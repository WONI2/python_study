# %%
import numpy as np
import pandas as pd

# !pip install folium
import folium
import json
import requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bb64b67-147c-4c71-9338-795f977bf208" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bb64b67-147c-4c71-9338-795f977bf208">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
embell= pd.read_excel('embell.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
embell.head()
# Out:
#    번호 안전비상벨관리번호 설치목적 설치장소유형                                설치위치  \
# 0   1     A2041  방범용     공원    서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)
# 1   2     A2042  방범용     공원         서울특별시 관악구 당곡2길 112 (상도근린공원)
# 2   3     A3001  방범용     공원    서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)
# 3   4     A3002  방범용     공원   서울특별시 관악구 난곡동 산 90-2 (일삼별공원 농구코트)
# 4   5     A3003  방범용     공원  서울특별시 관악구 남현동 산 65 (관음사지구 둘레길화장실앞)
#
#                            소재지도로명주소                             소재지지번주소  \
# 0  서울특별시 관악구 봉천로33가길 19-10 (한뼘동래공원)                                 NaN
# 1       서울특별시 관악구 당곡2길 112 (상도근린공원)                                 NaN
# 2  서울특별시 관악구 법원단지18길 31 (남강창의어린이공원)                                 NaN
# 3                               NaN   서울특별시 관악구 난곡동 산 90-2 (일삼별공원 농구코트)
# 4                               NaN  서울특별시 관악구 남현동 산 65 (관음사지구 둘레길화장실앞)
#
#      WGS84위도     WGS84경도 연계방식 경찰연계유무 경비업체연계유무 관리사무소연계유무  부가기능  안전비상벨설치연도  \
# ...

# %%
embell.tail()
# Out:
#         번호 안전비상벨관리번호 설치목적 설치장소유형        설치위치              소재지도로명주소 소재지지번주소  \
# 2028  2029     DG062  방범용     기타    장군봉7길 23    서울특별시 관악구 장군봉7길 23     NaN
# 2029  2030     DG063  방범용     기타   난곡로76길 13   서울특별시 관악구 난곡로76길 13     NaN
# 2030  2031     DG064  방범용     기타  조원중앙로 35-2  서울특별시 관악구 조원중앙로 35-2     NaN
# 2031  2032     DG065  방범용     기타     미성1길 14     서울특별시 관악구 미성1길 14     NaN
# 2032  2033     DG066  방범용     기타   난곡로 96-10   서울특별시 관악구 난곡로 96-10     NaN
#
#        WGS84위도    WGS84경도 연계방식 경찰연계유무 경비업체연계유무 관리사무소연계유무 부가기능  안전비상벨설치연도  \
# 2028  37.48037  126.94053  양방향      Y        N         N  NaN       2020
# 2029  37.48636  126.91430  양방향      Y        N         N  NaN       2020
# 2030  37.48287  126.90623  양방향      Y        N         N  NaN       2020
# 2031  37.47411  126.91694  양방향      Y        N         N  NaN       2020
# 2032  37.46347  126.91943  양방향      Y        N         N  NaN       2020
#
#           최종점검일자 최종점검결과구분 관리기관명     관리기관전화번호     데이터기준일자
# ...

# %%
map_osm = folium.Map(location = [37.478109,126.951492],zoom_start=14)

# %%
embell['WGS84위도'][7]
# Out:
# 37.48097851

# %%
for i in range(len(embell)):
  folium.Circle([embell['WGS84위도'][i],embell['WGS84경도'][i]],radius=10, color = 'blue').add_to(map_osm2)

# %%
map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d86b820-ddbf-483f-afd8-a777f07ec40a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d86b820-ddbf-483f-afd8-a777f07ec40a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
safe= pd.read_csv('서울시상권안전지수.csv')

# %%
safe
# Out:
#        10014910   상권  관광특구    1001491  2019  1                이태원 관광특구  \
# 0      10014920   상권  관광특구  1001492.0  2019  1  명동 남대문 북창동 다동 무교동 관광특구
# 1      10014930   상권  관광특구  1001493.0  2019  1            동대문패션타운 관광특구
# 2      10014940   상권  관광특구  1001494.0  2019  1              종로·청계 관광특구
# 3      10014950   상권  관광특구  1001495.0  2019  1                 잠실 관광특구
# 4      10014960   상권  관광특구  1001496.0  2019  1             강남 마이스 관광특구
# ...         ...  ...   ...        ...   ... ..                     ...
# 25122  11290590  행정동   NaN        NaN  2021  4                     NaN
# 25123  11350580  행정동   NaN        NaN  2021  4                     NaN
# 25124  11350612  행정동   NaN        NaN  2021  4                     NaN
# 25125  11350621  행정동   NaN        NaN  2021  4                     NaN
# 25126  11350700  행정동   NaN        NaN  2021  4                     NaN
#
#             이태원제1동  11170650    Blue Yellow Blue.1  Orange  Blue.2
# ...

# %%
place= pd.read_excel('안심벨 점수부여ver6.xlsx')
place
# Out:
#       Unnamed: 0         위도          경도      총 점수  \
# 0              0  37.475675  126.970732  0.324000
# 1              1  37.468030  126.945548  0.348000
# 2              2  37.468323  126.945460  0.348000
# 3              3  37.479596  126.937537  0.390890
# 4              4  37.475251  126.976448  0.272244
# ...          ...        ...         ...       ...
# 1554        1554  37.480370  126.940530  0.440780
# 1555        1555  37.486360  126.914300  0.319000
# 1556        1556  37.482870  126.906230  0.288890
# 1557        1557  37.474110  126.916940  0.197000
# 1558        1558  37.463470  126.919430  0.132000
#
#                                                      주소   유흥업소 점수   숙박업소 점수
# 0                    관악까치자연길, 행운동, 관악구, 서울, 07018, 대한민국  0.000000  0.000000
# 1     관악산역 1번출구, 신림로3길, 녹두거리, 대학동, 관악구, 서울, 08793, 대한민국  0.000000  0.000000
# 2     관악산역 1번출구, 신림로3길, 녹두거리, 대학동, 관악구, 서울, 08793, 대한민국  0.000000  0.000000
# ...

# %%
place_sorted_score = place.sort_values(by='총 점수', ascending=False)[0:100]
place_sorted_score
# Out:
#       Unnamed: 0         위도          경도      총 점수  \
# 609          609  37.485682  126.926504  0.712000
# 1076        1076  37.485680  126.926500  0.712000
# 1302        1302  37.485680  126.926500  0.712000
# 252          252  37.486470  126.925551  0.709110
# 1430        1430  37.486470  126.925550  0.709110
# ...          ...        ...         ...       ...
# 678          678  37.481709  126.924891  0.480488
# 1238        1238  37.482730  126.923270  0.480488
# 1040        1040  37.479530  126.949560  0.478354
# 558          558  37.479626  126.948545  0.478354
# 406          406  37.479530  126.949563  0.478354
#
#                                                      주소   유흥업소 점수   숙박업소 점수
# 609                   신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 1076                  신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 1302                  신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# ...

# %%
top100_score = place_sorted_score[0:100]
top100_score
# Out:
#     index  Unnamed: 0         위도          경도      총 점수  \
# 0     609         609  37.485682  126.926504  0.712000
# 1    1076        1076  37.485680  126.926500  0.712000
# 2    1302        1302  37.485680  126.926500  0.712000
# 3     252         252  37.486470  126.925551  0.709110
# 4    1430        1430  37.486470  126.925550  0.709110
# ..    ...         ...        ...         ...       ...
# 95    678         678  37.481709  126.924891  0.480488
# 96   1238        1238  37.482730  126.923270  0.480488
# 97   1040        1040  37.479530  126.949560  0.478354
# 98    558         558  37.479626  126.948545  0.478354
# 99    406         406  37.479530  126.949563  0.478354
#
#                                                    주소   유흥업소 점수   숙박업소 점수
# 0                   신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 1                   신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 2                   신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# ...

# %%
map_osm = folium.Map(location = [37.478109,126.951492],zoom_start=15)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# top100_score.reset_index
top100_score.set_index
# Out:
# <bound method DataFrame.set_index of       Unnamed: 0         위도          경도      총 점수  \
# 609          609  37.485682  126.926504  0.712000
# 1076        1076  37.485680  126.926500  0.712000
# 1302        1302  37.485680  126.926500  0.712000
# 252          252  37.486470  126.925551  0.709110
# 1430        1430  37.486470  126.925550  0.709110
# ...          ...        ...         ...       ...
# 678          678  37.481709  126.924891  0.480488
# 1238        1238  37.482730  126.923270  0.480488
# 1040        1040  37.479530  126.949560  0.478354
# 558          558  37.479626  126.948545  0.478354
# 406          406  37.479530  126.949563  0.478354
#
#                                                      주소   유흥업소 점수   숙박업소 점수
# 609                   신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 1076                  신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# 1302                  신림동5나길, 신림동, 관악구, 서울, 08707, 대한민국  0.000115  0.237115
# ...

# %%
top100_score2 = place_sorted_score.reset_index(inplace=True)
top100_score2

# %%
top100_score2

# %%
for i in range(len(top100_score)):
  folium.Circle([top100_score['위도'][i],top100_score['경도'][i]],radius=10, color = 'blue').add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
